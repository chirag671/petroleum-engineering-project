# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.interpolate import interp1d
from scipy.integrate import quad
import plotly.express as px
import numpy as np
import plotly.graph_objects as go

# %%
df=pd.read_excel('C:\\Users\\dell\\Downloads//drawdown.xlsx','Sheet1')
df.head()
# Out:
#    time    pw  pi-pwf
# 0  0.00  4412       0
# 1  0.12  3812     600
# 2  1.94  3699     713
# 3  2.79  3653     759
# 4  4.01  3636     776

# %% [raw]
# formation thickness20
# formation porosity0.23
# enter Initial water saturation0.26
# enter total compressibilty6e-6
# enter oil viscosity0.42
# enter formation volume factor1.45
# enter wellbore radius0.5
# enter constant flow rate550
# enter total elapsed time725
# enter tubing area0.0218
# enter liquid density53
# case-1 example from john lee book

# %%
A_tubing=float(input('enter tubing area'))
rho=float(input('enter liquid density'))
# Out:
# enter tubing area0.0218
# enter liquid density53

# %%
h1=float(input('formation thickness'))
phi1=float(input('formation porosity'))
SW1=float(input('enter Initial water saturation' ))
Ct1=float(input('enter total compressibilty' ))
muo1=float(input('enter oil viscosity'))
Bo1=float(input('enter formation volume factor'))
rw1=float(input('enter wellbore radius'))
q1=float(input('enter constant flow rate'))
t1=float(input('enter total elapsed time'))
# Out:
# formation thickness20
# formation porosity0.23
# enter Initial water saturation0.26
# enter total compressibilty6e-6
# enter oil viscosity0.42
# enter formation volume factor1.45
# enter wellbore radius0.5
# enter constant flow rate550
# enter total elapsed time725

# %%
tpss=948*phi1*muo1*Ct1*2500**2/38
tpss
# Out:
# 90.37184210526316

# %% [markdown]
# case-1 example from john lee book

# %%
plt.plot(df['time'].loc[2:],df['pw'].loc[2:],'b')
plt.xscale('log')
plt.yscale('log')
plt.grid(color='hotpink')

#cartesian plot

# %% [markdown]
# it is evident that wellbore storage effects ended approximately after one (1) hour of flow. Applying the one-and-half cycle rule of thumb, the flow test was definitely in the MTR after 50 hours of flow. Boundary effects appear to start after 200 hours of flow. Thus, the MTR straight line was drawn between flow time of 50 hrs and 200 hrs.

# %%
#plt.semilogx(df['time'],df['pw'])
plt.plot(df['time'].loc[2:],df['pw'].loc[2:],label='pwf vs t',color='blue')
plt.grid(color='hotpink')
plt.xlabel('time')
plt.ylabel('pfw')
plt.legend(loc='lower right' ,bbox_to_anchor=(0.1,0.1))
plt.xscale('log')
pw_f=interp1d(df['time'],df['pw'],'linear')
pw_f(12)
#according to semilog graph -;devaition show that MTR beigin at t=12 hours and end at t=neart to 150 hour
plt.axvline(x=12,label='begining of MTR region',color='red')
plt.axvline(x=150,label='end of MTR region',color='red')
plt.legend()
pw_f(260)
pw_f(10)
t_initMTR=12
t_endMTR=150

# %%
fig=px.scatter(x=df['time'].loc[2:],y=df['pw'].loc[2:],log_x=True})
fig.show()
# Out:
#   Input In [28]
#     fig=px.scatter(x=df['time'].loc[2:],y=df['pw'].loc[2:],log_x=True})
#                                                                      ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '('

# %%
#fig=px.line(x=df['time'].loc[2:],y=df['pw'].loc[2:],log_x=True)
fig=go.Figure()
#df=px.data.gapminder().query(['pwf vs t','begining of MTR region','end of MTR region'])
fig=px.line(df.loc[2:],x='time',y='pw',log_x=True)

#fig.add_trace(go.Scatter((12,0),mode='lines',name='begining of MTR region'))
fig.add_vline(x=90)
fig.add_vline(x=10)

#21`fig.update_layout(legend_traceorder='reversed')
fig.show()
# Out:
# <div>                            <div id="52003791-198d-4ee2-b705-25a6751f3c86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52003791-198d-4ee2-b705-25a6751f3c86")) {                    Plotly.newPlot(                        "52003791-198d-4ee2-b705-25a6751f3c86",                        [{"hovertemplate":"time=%{x}<br>pw=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1.94,2.79,4.01,4.82,5.78,6.94,9.32,9.99,14.4,17.3,20.7,24.9,29.8,35.8,43.0,51.5,61.8,74.2,89.1,107.0,128.0,154.0,185.0,222.0,266.0,319.0,383.0,460.0],"xaxis":"x","y":[3699,3653,3636,3616,3607,3600,3593,3586,3573,3567,3561,3555,3549,3544,3537,3532,3526,3521,
# ...

# %%
###The slope of the MTR straight line was determined one cycle apart between as:###
m1=pw_f(10)-pw_f(100)

#m1 according to my logic i have taken this according to john lee m=70
m=70
m1
m2=67.83

# %%
k1=(162.6*q*Bo*muo)/(m1*h)

k2=(162.6*q*Bo*muo)/(m2*h)

s1=1.151*((-np.log(k1/(phi*muo*Ct*rw**2))+3.23+(pi-p_1hr)/m1))
s1
k1
s1
k2
s2=1.151*((-np.log(k2/(phi*muo*Ct*rw**2))+3.23+(pi-p_1hr)/m1))
s2
# Out:
# -8.922740927686363

# %%
k=(162.6*q1*Bo1*muo1)/(m*h1)
k#permeability
k
#s=1.151*(3.23+(pi-p_1hr)/m-np.log(k/(phi*muo*Ct*rw**2)))
#s
k
# Out:
# 38.902049999999996

# %%
### radius of investigation at begining and end of mtr
#at t=12
import numpy as np
r1_12=np.sqrt((k1*t_initMTR)/(948*phi*muo*Ct))
r1_12

# %%
r_12=np.sqrt((k*t_initMTR)/(948*phi*muo*Ct))
r_12
# Out:
# 427.2435996144526

# %%
r1_150=np.sqrt((k1*t_endMTR)/(948*phi*muo*Ct))
r1_150
# Out:
# 1462.9850395018987

# %%
r_150=np.sqrt((k*t_endMTR)/(948*phi*muo*Ct))
r_150
# Out:
# 1510.5342325296485

# %%
# pressure at t =1 hour
p_1hr=pw_f(1)
pi=4412 #inital reservior pressure
p_1hr
# Out:
# array(3757.36263736)

# %%
C_wellborestorage=25.65*A_tubing/rho
C_wellborestorage
# Out:
# 0.010550377358490565

# %%
T_wbs1=((200000+12000*s)*C_wellborestorage)/((k*h)/0.8)
T_wbs
# Out:
# 1.743293555070898

# %%
T1_wbs1=((200000+12000*s1)*C_wellborestorage)/((k1*h)/0.8)
T1_wbs1
# Out:
# 1.6068287658851117

# %%
plt.plot(df['time'].loc[2:],df['pi-pwf'].loc[2:],label='semilog',color='blue')
plt.xscale('log')
plt.yscale('log')
plt.grid(color='hotpink')
plt.axvline(x=260)

# %%
case-2# confusing if anyone want solve can solve

# %%
df1=pd.read_excel('C:\\Users\\dell\\Downloads//drawdown.xlsx','Sheet4')
df1.head()
# Out:
#    time   pwf
# 0  0.00  5665
# 1  0.12  5645
# 2  0.22  5615
# 3  0.42  5590
# 4  0.62  5577

# %%
#plt.semilogx(df['time'],df['pw'])
plt.plot(df1['time'].loc[5:],df1['pwf'].loc[5:],label='semilog',color='blue')
plt.grid(color='hotpink')
plt.xlabel('time')
plt.ylabel('pwf')
plt.legend()
plt.xscale('log')
pw_f=interp1d(df1['time'],df1['pwf'],'linear')
pw_f(1)
#plt.axvline(x=30)
plt.axvline(x=50)
plt.axvline(x=250)
#plt.axvline(x=10,color='red')
#plt.axvline(x=100,color='red')
